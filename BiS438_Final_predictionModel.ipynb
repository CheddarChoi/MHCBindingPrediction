# %%
import os
import keras
import urllib.request
from google.colab import drive
import numpy as np
import pandas as pd
# !pip install Bio
from Bio.SubsMat import MatrixInfo

import keras
import tensorflow as tf
from keras.preprocessing import sequence
from keras.models import Sequential, Model
from keras.layers import Conv1D, Dense, Dropout, Flatten, Input, MaxPooling1D, LSTM, Concatenate
from keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, roc_curve, auc
import matplotlib.pyplot as plt
# Out:
# Requirement already satisfied: Bio in /usr/local/lib/python3.6/dist-packages (0.2.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from Bio) (2.23.0)
# Requirement already satisfied: biopython>=1.78 in /usr/local/lib/python3.6/dist-packages (from Bio) (1.78)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->Bio) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->Bio) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->Bio) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->Bio) (1.24.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from biopython>=1.78->Bio) (1.18.5)

# %%
## Functions for data processing
target_alleles=['HLA-A02:01', 'HLA-A03:01', 'HLA-A11:01', 'HLA-A02:03', 'HLA-A31:01', 'HLA-A02:06', 'HLA-A68:02']

blosum = MatrixInfo.blosum62
all_amino = "ARNDCQEGHILKMFPSTWYV"

def blosum_line(key):
  result = []
  for amino in all_amino:
    try:
      result.append(blosum[(amino,key)])
    except:
      result.append(blosum[(key,amino)])
  return result

def protein_mapping(categorical=False):
  map = dict(zip(all_amino, range(20)))
  mapping = dict()
  for (key, value) in map.items():
    if categorical:
      new_list = [0] * 20
      new_list[value] = 1
      mapping[key] = new_list
    else:
      mapping[key] = blosum_line(key)
  mapping['_'] = [0] * 20
  return mapping

protein_map = protein_mapping(categorical = False)

def one_hot_encode(seq):
    seq2 = [protein_map[i] for i in seq]
    seq_array = np.asarray(seq2)
    return seq2

import sklearn.preprocessing

def file_to_data(filename):
  print("convert "+filename+" in to sequence and label dataset")
  dataset = pd.read_csv(filename, delimiter='\t', header=0)

  # Convert sequence data
  input_sequence = []
  for sequence in dataset.peptide:
    adjusted_sequence = sequence
    if len(sequence) < 20:
      adjusted_sequence += '_'*(20-len(sequence))
    assert len(adjusted_sequence) == 20
    input_sequence.append(one_hot_encode(adjusted_sequence))
  input_sequence = np.array(input_sequence)

  # Convert label data
  input_label = np.array(dataset.label_num)
  input_label = keras.utils.to_categorical(input_label, 2)

  # Convert allele data
  input_allele = []
  for d in dataset.allele:
    idx = target_alleles.index(d)
    l = [0]*7
    l[idx] = 1
    input_allele.append(l)
  input_allele = np.array(input_allele)

  return ((input_sequence, input_allele), input_label)

# %%
## DNN model
input_sequence = Input((20,20))
input_allele = Input((7,))
flat_layer = Flatten()(input_sequence)
concat_layer= Concatenate()([input_allele, flat_layer])
layer_1 = Dense(280, activation='relu')(concat_layer)
layer_1_dropout = Dropout(0.4)(layer_1)
layer_2 = Dense(90, activation='relu')(concat_layer)
layer_2_dropout = Dropout(0.3)(layer_2)
output_layer = Dense(2, activation='softmax')(layer_2_dropout)
DNN_model_default = Model(inputs=[input_sequence, input_allele], outputs=output_layer)

## RDNN model
input_sequence = Input((20,20))
input_allele = Input((7,))
lstm_layer = LSTM(20)(input_sequence)
flat_layer = Flatten()(lstm_layer)
concat_layer= Concatenate()([input_allele, flat_layer])
layer_1 = Dense(280, activation='relu')(concat_layer)
layer_1_dropout = Dropout(0.4)(layer_1)
layer_2 = Dense(90, activation='relu')(concat_layer)
layer_2_dropout = Dropout(0.3)(layer_2)
output_layer = Dense(2, activation='softmax')(layer_2_dropout)
RDNN_model_default = Model(inputs=[input_sequence, input_allele], outputs=output_layer)

## CDNN model
input_sequence = Input((20,20))
input_allele = Input((7,))
conv_layer = Conv1D(filters=256, kernel_size=4, activation="relu")(input_sequence)
maxpool_layer = MaxPooling1D(pool_size=11, strides=1)(conv_layer)
flat_layer = Flatten()(maxpool_layer)
concat_layer= Concatenate()([input_allele, flat_layer])
layer_1 = Dense(280, activation='relu')(concat_layer)
layer_1_dropout = Dropout(0.4)(layer_1)
layer_2 = Dense(90, activation='relu')(concat_layer)
layer_2_dropout = Dropout(0.3)(layer_2)
output_layer = Dense(2, activation='softmax')(layer_2_dropout)
CDNN_model_default = Model(inputs=[input_sequence, input_allele], outputs=output_layer)

## RCDNN model
input_sequence = Input((20,20))
input_allele = Input((7,))
conv_layer = Conv1D(filters=256, kernel_size=4, activation="relu")(input_sequence)
maxpool_layer = MaxPooling1D(pool_size=11, strides=1)(conv_layer)
lstm_layer = LSTM(20)(maxpool_layer)
flat_layer = Flatten()(lstm_layer)
concat_layer= Concatenate()([input_allele, flat_layer])
layer_1 = Dense(280, activation='relu')(concat_layer)
layer_1_dropout = Dropout(0.4)(layer_1)
layer_2 = Dense(90, activation='relu')(concat_layer)
layer_2_dropout = Dropout(0.3)(layer_2)
output_layer = Dense(2, activation='softmax')(layer_2_dropout)
RCDNN_model_default = Model(inputs=[input_sequence, input_allele], outputs=output_layer)

# %%
drive.mount('/content/gdrive')
processed_file_path = 'gdrive/My Drive/data sample/NetMHCpan_processed/'
print('list of files', os.listdir(processed_file_path))
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# list of files ['train_HLA-A02:01.tsv', 'train_HLA-A03:01.tsv', 'train_HLA-A02:03.tsv', 'train_HLA-A02:06.tsv', 'train_HLA-A11:01.tsv', 'train_HLA-A68:02.tsv', 'train_HLA-A31:01.tsv', 'train_all.tsv', 'test_HLA-A11:01.tsv', 'test_HLA-A03:01.tsv', 'test_HLA-A68:02.tsv', 'test_HLA-A31:01.tsv', 'test_HLA-A02:01.tsv', 'test_HLA-A02:03.tsv', 'test_HLA-A02:06.tsv', 'test_all.tsv']

# %%
## Function for model evaluation

def evaluation(test_data, model, hist, file_name, model_name=""):
  (test_sequence, test_label) = test_data

  print("Evaluation for "+model_name)
  
  # Print the result of model
  loss, accuracy = model.evaluate(test_sequence, test_label)
  print('Result of model with test set')
  print('loss value: \t'+str(loss))
  print('accuracy value: '+str(accuracy)+'\n')

  # Plot loss function
  plt.figure(figsize=(12,5))
  plt.subplot(1,2,1)
  plt.plot(hist.history['loss'])
  plt.plot(hist.history['val_loss'])
  plt.xlabel('epoch')
  plt.ylabel('loss')
  plt.title('loss for '+model_name+' model')
  plt.legend(['train', 'valid'])

  # Plot accuracy
  plt.subplot(1,2,2)
  plt.plot(hist.history['accuracy'])
  plt.plot(hist.history['val_accuracy'])
  plt.xlabel('epoch')
  plt.ylabel('accuracy')
  plt.title('accuracy for '+model_name+' model')
  plt.legend(['train', 'valid'])

  plt.savefig(file_name+'_loss_accuracy.png', dpi=300)

  # Prediction data
  test_prediction = model.predict(test_sequence)
  test_prediction = [np.argmax(y) for y in test_prediction] # convert predicted label to one-hot encoding
  test_Y = [np.argmax(y) for y in test_label]               # convert label to one-hot encoding
  print(classification_report(test_Y, test_prediction))     # Print classification report

  # Draw ROC-curve and calculate ROC-AUC
  fpr, tpr, thresholds = roc_curve(test_Y, test_prediction, pos_label=1)  # Calculate fpr, tpr to calculate ROC-AUC

  # Plot ROC-curve
  plt.figure()
  plt.plot(fpr, tpr)
  plt.plot([0,1], [0,1], '--k')
  plt.xlabel('false positive rate')
  plt.ylabel('true positive rate')
  plt.title('AR roc curve for '+model_name+" model")

  plt.savefig(file_name+'_ROC.png', dpi=300)

  # Calculate & Print ROC-AUC
  print('ROC-AUC of the '+model_name+' model : ' + str(auc(fpr, tpr)), end='\n')

  return (loss, accuracy, auc(fpr, tpr))

# %%
def modeling():
  target_filename = processed_file_path+"train_all.tsv"

  ((input_sequence, input_allele), input_label) = file_to_data(target_filename)

  train_sequence, validation_sequence, train_label, validation_label = train_test_split(input_sequence, input_label, test_size=0.2, random_state=777)
  train_allele, validation_allele, train_label, validation_label = train_test_split(input_allele, input_label, test_size=0.2, random_state=777)
  print('Dataset preparation done... train_sequence, train_label, train_allele, validation_allele, validation_sequence, validation_label')
  print('Size of each set...', train_sequence.shape, train_label.shape, train_allele.shape, validation_allele.shape, validation_sequence.shape, validation_label.shape)

  epochs = 50
  batch_size = 64

  DNN_model = keras.models.clone_model(DNN_model_default)
  DNN_model.summary()

  DNN_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
  
  es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=5)
  mc = ModelCheckpoint('best_model_DNN.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)
  hist_DNN = DNN_model.fit((train_sequence, train_allele), train_label, 
                         validation_data=((validation_sequence, validation_allele), validation_label), 
                         batch_size=batch_size, epochs=epochs, verbose=0, callbacks=[es, mc])

  CDNN_model = keras.models.clone_model(CDNN_model_default)
  CDNN_model.summary()

  CDNN_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

  es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=5)
  mc = ModelCheckpoint('best_model_CDNN.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)
  hist_CDNN = CDNN_model.fit((train_sequence, train_allele), train_label, 
                           validation_data=((validation_sequence, validation_allele), validation_label), 
                           batch_size=batch_size, epochs=epochs, verbose=0, callbacks=[es, mc])
  
  RDNN_model = keras.models.clone_model(RDNN_model_default)
  RDNN_model.summary()

  RDNN_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

  es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=5)
  mc = ModelCheckpoint('best_model_RDNN.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)
  hist_RDNN = RDNN_model.fit((train_sequence, train_allele), train_label, 
                           validation_data=((validation_sequence, validation_allele), validation_label), 
                           batch_size=batch_size, epochs=epochs, verbose=0, callbacks=[es, mc])
  
  RCDNN_model = keras.models.clone_model(RCDNN_model_default)
  RCDNN_model.summary()

  RCDNN_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

  es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=5)
  mc = ModelCheckpoint('best_model_RCDNN.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)
  hist_RCDNN = RCDNN_model.fit((train_sequence, train_allele), train_label, 
                           validation_data=((validation_sequence, validation_allele), validation_label), 
                           batch_size=batch_size, epochs=epochs, verbose=0, callbacks=[es, mc])

  return (len(input_sequence), (DNN_model, hist_DNN), (CDNN_model, hist_CDNN), (RDNN_model, hist_RDNN), (RCDNN_model, hist_RCDNN))

def model_evaluation(model, hist, model_name=""):
  target_filename = processed_file_path+"test_all.tsv"
  ((test_sequence, test_allele), test_label) = file_to_data(target_filename)

  (loss, accuracy, auc) = evaluation(((test_sequence, test_allele), test_label), model, hist, "all", model_name)

  return (loss, accuracy, auc)

# %%
result = dict()
(sample_num, (model_DNN, hist_DNN), (model_CDNN, hist_CDNN), (model_RDNN, hist_RDNN), (model_RCDNN, hist_RCDNN)) = modeling()
(loss_DNN, accuracy_DNN, auc_DNN) = model_evaluation(model_DNN, hist_DNN, model_name="DNN")
(loss_CDNN, accuracy_CDNN, auc_CDNN) = model_evaluation(model_CDNN, hist_CDNN, model_name="CDNN")
(loss_RDNN, accuracy_RDNN, auc_RDNN) = model_evaluation(model_RDNN, hist_RDNN, model_name="RDNN")
(loss_RCDNN, accuracy_RCDNN, auc_RCDNN) = model_evaluation(model_RCDNN, hist_RCDNN, model_name="RCDNN")
result = {"num":sample_num, 
          "DNN":{"loss":loss_DNN, "accuracy":accuracy_DNN, "auc":auc_DNN}, 
          "CDNN":{"loss":loss_CDNN, "accuracy":accuracy_CDNN, "auc":auc_CDNN},
          "RDNN":{"loss":loss_RDNN, "accuracy":accuracy_RDNN, "auc":auc_RDNN},
          "RCDNN":{"loss":loss_RCDNN, "accuracy":accuracy_RCDNN, "auc":auc_RCDNN}}
# Out:
# convert gdrive/My Drive/data sample/NetMHCpan_processed/train_all.tsv in to sequence and label dataset
# Dataset preparation done... train_sequence, train_label, train_allele, validation_allele, validation_sequence, validation_label
# Size of each set... (156908, 20, 20) (156908, 2) (156908, 7) (39228, 7) (39228, 20, 20) (39228, 2)
# Model: "functional_12"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_22 (InputLayer)           [(None, 20, 20)]     0
# __________________________________________________________________________________________________
# input_23 (InputLayer)           [(None, 7)]          0
# __________________________________________________________________________________________________
# flatten_12 (Flatten)            (None, 400)          0           input_22[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 407)          0           input_23[0][0]
#                                                                  flatten_12[0][0]
# __________________________________________________________________________________________________
# dense_34 (Dense)                (None, 90)           36720       concatenate_8[0][0]
# __________________________________________________________________________________________________
# dropout_23 (Dropout)            (None, 90)           0           dense_34[0][0]
# __________________________________________________________________________________________________
# dense_35 (Dense)                (None, 2)            182         dropout_23[0][0]
# ==================================================================================================
# Total params: 36,902
# Trainable params: 36,902
# Non-trainable params: 0
# __________________________________________________________________________________________________
#
# Epoch 00001: val_accuracy improved from -inf to 0.83183, saving model to best_model_DNN.h5
#
# Epoch 00002: val_accuracy improved from 0.83183 to 0.85653, saving model to best_model_DNN.h5
#
# Epoch 00003: val_accuracy improved from 0.85653 to 0.87065, saving model to best_model_DNN.h5
#
# Epoch 00004: val_accuracy improved from 0.87065 to 0.87244, saving model to best_model_DNN.h5
#
# Epoch 00005: val_accuracy improved from 0.87244 to 0.88574, saving model to best_model_DNN.h5
#
# Epoch 00006: val_accuracy improved from 0.88574 to 0.88924, saving model to best_model_DNN.h5
#
# Epoch 00007: val_accuracy improved from 0.88924 to 0.89732, saving model to best_model_DNN.h5
#
# Epoch 00008: val_accuracy improved from 0.89732 to 0.89783, saving model to best_model_DNN.h5
#
# Epoch 00009: val_accuracy improved from 0.89783 to 0.89971, saving model to best_model_DNN.h5
#
# Epoch 00010: val_accuracy improved from 0.89971 to 0.90282, saving model to best_model_DNN.h5
#
# Epoch 00011: val_accuracy improved from 0.90282 to 0.90494, saving model to best_model_DNN.h5
#
# Epoch 00012: val_accuracy improved from 0.90494 to 0.90571, saving model to best_model_DNN.h5
#
# Epoch 00013: val_accuracy improved from 0.90571 to 0.91080, saving model to best_model_DNN.h5
#
# Epoch 00014: val_accuracy improved from 0.91080 to 0.91106, saving model to best_model_DNN.h5
#
# Epoch 00015: val_accuracy improved from 0.91106 to 0.91180, saving model to best_model_DNN.h5
#
# Epoch 00016: val_accuracy improved from 0.91180 to 0.91549, saving model to best_model_DNN.h5
#
# Epoch 00017: val_accuracy did not improve from 0.91549
#
# Epoch 00018: val_accuracy improved from 0.91549 to 0.91881, saving model to best_model_DNN.h5
#
# Epoch 00019: val_accuracy did not improve from 0.91881
#
# Epoch 00020: val_accuracy improved from 0.91881 to 0.92182, saving model to best_model_DNN.h5
#
# Epoch 00021: val_accuracy did not improve from 0.92182
#
# Epoch 00022: val_accuracy improved from 0.92182 to 0.92238, saving model to best_model_DNN.h5
#
# Epoch 00023: val_accuracy did not improve from 0.92238
#
# Epoch 00024: val_accuracy improved from 0.92238 to 0.92388, saving model to best_model_DNN.h5
#
# Epoch 00025: val_accuracy improved from 0.92388 to 0.92406, saving model to best_model_DNN.h5
#
# Epoch 00026: val_accuracy did not improve from 0.92406
#
# Epoch 00027: val_accuracy improved from 0.92406 to 0.92449, saving model to best_model_DNN.h5
#
# Epoch 00028: val_accuracy improved from 0.92449 to 0.92760, saving model to best_model_DNN.h5
#
# Epoch 00029: val_accuracy did not improve from 0.92760
#
# Epoch 00030: val_accuracy improved from 0.92760 to 0.92883, saving model to best_model_DNN.h5
#
# Epoch 00031: val_accuracy did not improve from 0.92883
#
# Epoch 00032: val_accuracy did not improve from 0.92883
#
# Epoch 00033: val_accuracy improved from 0.92883 to 0.92923, saving model to best_model_DNN.h5
#
# Epoch 00034: val_accuracy did not improve from 0.92923
#
# Epoch 00035: val_accuracy improved from 0.92923 to 0.93104, saving model to best_model_DNN.h5
#
# Epoch 00036: val_accuracy improved from 0.93104 to 0.93275, saving model to best_model_DNN.h5
#
# Epoch 00037: val_accuracy did not improve from 0.93275
#
# Epoch 00038: val_accuracy did not improve from 0.93275
#
# Epoch 00039: val_accuracy improved from 0.93275 to 0.93308, saving model to best_model_DNN.h5
#
# Epoch 00040: val_accuracy improved from 0.93308 to 0.93522, saving model to best_model_DNN.h5
#
# Epoch 00041: val_accuracy did not improve from 0.93522
#
# Epoch 00042: val_accuracy did not improve from 0.93522
#
# Epoch 00043: val_accuracy did not improve from 0.93522
#
# Epoch 00044: val_accuracy improved from 0.93522 to 0.93530, saving model to best_model_DNN.h5
#
# Epoch 00045: val_accuracy improved from 0.93530 to 0.93709, saving model to best_model_DNN.h5
#
# Epoch 00046: val_accuracy improved from 0.93709 to 0.93777, saving model to best_model_DNN.h5
#
# Epoch 00047: val_accuracy did not improve from 0.93777
#
# Epoch 00048: val_accuracy did not improve from 0.93777
#
# Epoch 00049: val_accuracy did not improve from 0.93777
#
# Epoch 00050: val_accuracy did not improve from 0.93777
# Model: "functional_16"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_26 (InputLayer)           [(None, 20, 20)]     0
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 17, 256)      20736       input_26[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_4 (MaxPooling1D)  (None, 7, 256)       0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# input_27 (InputLayer)           [(None, 7)]          0
# __________________________________________________________________________________________________
# flatten_14 (Flatten)            (None, 1792)         0           max_pooling1d_4[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 1799)         0           input_27[0][0]
#                                                                  flatten_14[0][0]
# __________________________________________________________________________________________________
# dense_40 (Dense)                (None, 90)           162000      concatenate_10[0][0]
# __________________________________________________________________________________________________
# dropout_27 (Dropout)            (None, 90)           0           dense_40[0][0]
# __________________________________________________________________________________________________
# dense_41 (Dense)                (None, 2)            182         dropout_27[0][0]
# ==================================================================================================
# Total params: 182,918
# Trainable params: 182,918
# Non-trainable params: 0
# __________________________________________________________________________________________________
#
# Epoch 00001: val_accuracy improved from -inf to 0.76644, saving model to best_model_CDNN.h5
#
# Epoch 00002: val_accuracy improved from 0.76644 to 0.79866, saving model to best_model_CDNN.h5
#
# Epoch 00003: val_accuracy improved from 0.79866 to 0.80524, saving model to best_model_CDNN.h5
#
# Epoch 00004: val_accuracy improved from 0.80524 to 0.82701, saving model to best_model_CDNN.h5
#
# Epoch 00005: val_accuracy improved from 0.82701 to 0.84712, saving model to best_model_CDNN.h5
#
# Epoch 00006: val_accuracy improved from 0.84712 to 0.85062, saving model to best_model_CDNN.h5
#
# Epoch 00007: val_accuracy improved from 0.85062 to 0.86298, saving model to best_model_CDNN.h5
#
# Epoch 00008: val_accuracy did not improve from 0.86298
#
# Epoch 00009: val_accuracy improved from 0.86298 to 0.87440, saving model to best_model_CDNN.h5
#
# Epoch 00010: val_accuracy did not improve from 0.87440
#
# Epoch 00011: val_accuracy improved from 0.87440 to 0.87952, saving model to best_model_CDNN.h5
#
# Epoch 00012: val_accuracy improved from 0.87952 to 0.88011, saving model to best_model_CDNN.h5
#
# Epoch 00013: val_accuracy improved from 0.88011 to 0.88671, saving model to best_model_CDNN.h5
#
# Epoch 00014: val_accuracy did not improve from 0.88671
#
# Epoch 00015: val_accuracy improved from 0.88671 to 0.88952, saving model to best_model_CDNN.h5
#
# Epoch 00016: val_accuracy improved from 0.88952 to 0.89597, saving model to best_model_CDNN.h5
#
# Epoch 00017: val_accuracy did not improve from 0.89597
#
# Epoch 00018: val_accuracy improved from 0.89597 to 0.90020, saving model to best_model_CDNN.h5
#
# Epoch 00019: val_accuracy improved from 0.90020 to 0.90257, saving model to best_model_CDNN.h5
#
# Epoch 00020: val_accuracy did not improve from 0.90257
#
# Epoch 00021: val_accuracy improved from 0.90257 to 0.90428, saving model to best_model_CDNN.h5
#
# Epoch 00022: val_accuracy improved from 0.90428 to 0.90907, saving model to best_model_CDNN.h5
#
# Epoch 00023: val_accuracy did not improve from 0.90907
#
# Epoch 00024: val_accuracy improved from 0.90907 to 0.91004, saving model to best_model_CDNN.h5
#
# Epoch 00025: val_accuracy did not improve from 0.91004
#
# Epoch 00026: val_accuracy improved from 0.91004 to 0.91435, saving model to best_model_CDNN.h5
#
# Epoch 00027: val_accuracy did not improve from 0.91435
#
# Epoch 00028: val_accuracy improved from 0.91435 to 0.91927, saving model to best_model_CDNN.h5
#
# Epoch 00029: val_accuracy improved from 0.91927 to 0.92046, saving model to best_model_CDNN.h5
#
# Epoch 00030: val_accuracy improved from 0.92046 to 0.92307, saving model to best_model_CDNN.h5
#
# Epoch 00031: val_accuracy improved from 0.92307 to 0.92411, saving model to best_model_CDNN.h5
#
# Epoch 00032: val_accuracy did not improve from 0.92411
#
# Epoch 00033: val_accuracy improved from 0.92411 to 0.92885, saving model to best_model_CDNN.h5
#
# Epoch 00034: val_accuracy did not improve from 0.92885
#
# Epoch 00035: val_accuracy did not improve from 0.92885
#
# Epoch 00036: val_accuracy improved from 0.92885 to 0.92957, saving model to best_model_CDNN.h5
#
# Epoch 00037: val_accuracy improved from 0.92957 to 0.93449, saving model to best_model_CDNN.h5
#
# Epoch 00038: val_accuracy did not improve from 0.93449
#
# Epoch 00039: val_accuracy did not improve from 0.93449
#
# Epoch 00040: val_accuracy improved from 0.93449 to 0.93716, saving model to best_model_CDNN.h5
#
# Epoch 00041: val_accuracy did not improve from 0.93716
#
# Epoch 00042: val_accuracy improved from 0.93716 to 0.93928, saving model to best_model_CDNN.h5
#
# Epoch 00043: val_accuracy did not improve from 0.93928
#
# Epoch 00044: val_accuracy did not improve from 0.93928
#
# Epoch 00045: val_accuracy improved from 0.93928 to 0.93951, saving model to best_model_CDNN.h5
#
# Epoch 00046: val_accuracy improved from 0.93951 to 0.94053, saving model to best_model_CDNN.h5
#
# Epoch 00047: val_accuracy improved from 0.94053 to 0.94231, saving model to best_model_CDNN.h5
#
# Epoch 00048: val_accuracy improved from 0.94231 to 0.94282, saving model to best_model_CDNN.h5
#
# Epoch 00049: val_accuracy did not improve from 0.94282
#
# Epoch 00050: val_accuracy improved from 0.94282 to 0.94478, saving model to best_model_CDNN.h5
# Model: "functional_14"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_24 (InputLayer)           [(None, 20, 20)]     0
# __________________________________________________________________________________________________
# lstm_4 (LSTM)                   (None, 20)           3280        input_24[0][0]
# __________________________________________________________________________________________________
# input_25 (InputLayer)           [(None, 7)]          0
# __________________________________________________________________________________________________
# flatten_13 (Flatten)            (None, 20)           0           lstm_4[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 27)           0           input_25[0][0]
#                                                                  flatten_13[0][0]
# __________________________________________________________________________________________________
# dense_37 (Dense)                (None, 90)           2520        concatenate_9[0][0]
# __________________________________________________________________________________________________
# dropout_25 (Dropout)            (None, 90)           0           dense_37[0][0]
# __________________________________________________________________________________________________
# dense_38 (Dense)                (None, 2)            182         dropout_25[0][0]
# ==================================================================================================
# Total params: 5,982
# Trainable params: 5,982
# Non-trainable params: 0
# __________________________________________________________________________________________________
#
# Epoch 00001: val_accuracy improved from -inf to 0.80733, saving model to best_model_RDNN.h5
#
# Epoch 00002: val_accuracy improved from 0.80733 to 0.82925, saving model to best_model_RDNN.h5
#
# Epoch 00003: val_accuracy improved from 0.82925 to 0.84159, saving model to best_model_RDNN.h5
#
# Epoch 00004: val_accuracy improved from 0.84159 to 0.84440, saving model to best_model_RDNN.h5
#
# Epoch 00005: val_accuracy improved from 0.84440 to 0.85085, saving model to best_model_RDNN.h5
#
# Epoch 00006: val_accuracy improved from 0.85085 to 0.85278, saving model to best_model_RDNN.h5
#
# Epoch 00007: val_accuracy improved from 0.85278 to 0.85673, saving model to best_model_RDNN.h5
#
# Epoch 00008: val_accuracy improved from 0.85673 to 0.85898, saving model to best_model_RDNN.h5
#
# Epoch 00009: val_accuracy improved from 0.85898 to 0.86160, saving model to best_model_RDNN.h5
#
# Epoch 00010: val_accuracy improved from 0.86160 to 0.86344, saving model to best_model_RDNN.h5
#
# Epoch 00011: val_accuracy did not improve from 0.86344
#
# Epoch 00012: val_accuracy improved from 0.86344 to 0.86352, saving model to best_model_RDNN.h5
#
# Epoch 00013: val_accuracy improved from 0.86352 to 0.86543, saving model to best_model_RDNN.h5
#
# Epoch 00014: val_accuracy did not improve from 0.86543
#
# Epoch 00015: val_accuracy did not improve from 0.86543
#
# Epoch 00016: val_accuracy improved from 0.86543 to 0.87042, saving model to best_model_RDNN.h5
#
# Epoch 00017: val_accuracy did not improve from 0.87042
#
# Epoch 00018: val_accuracy improved from 0.87042 to 0.87083, saving model to best_model_RDNN.h5
#
# Epoch 00019: val_accuracy did not improve from 0.87083
#
# Epoch 00020: val_accuracy did not improve from 0.87083
#
# Epoch 00021: val_accuracy did not improve from 0.87083
#
# Epoch 00022: val_accuracy did not improve from 0.87083
#
# Epoch 00023: val_accuracy did not improve from 0.87083
#
# Epoch 00024: val_accuracy improved from 0.87083 to 0.87519, saving model to best_model_RDNN.h5
#
# Epoch 00025: val_accuracy did not improve from 0.87519
#
# Epoch 00026: val_accuracy did not improve from 0.87519
#
# Epoch 00027: val_accuracy did not improve from 0.87519
#
# Epoch 00028: val_accuracy improved from 0.87519 to 0.87613, saving model to best_model_RDNN.h5
#
# Epoch 00029: val_accuracy improved from 0.87613 to 0.87777, saving model to best_model_RDNN.h5
#
# Epoch 00030: val_accuracy did not improve from 0.87777
#
# Epoch 00031: val_accuracy improved from 0.87777 to 0.87889, saving model to best_model_RDNN.h5
#
# Epoch 00032: val_accuracy did not improve from 0.87889
#
# Epoch 00033: val_accuracy did not improve from 0.87889
#
# Epoch 00034: val_accuracy did not improve from 0.87889
#
# Epoch 00035: val_accuracy did not improve from 0.87889
#
# Epoch 00036: val_accuracy did not improve from 0.87889
#
# Epoch 00037: val_accuracy improved from 0.87889 to 0.87914, saving model to best_model_RDNN.h5
#
# Epoch 00038: val_accuracy improved from 0.87914 to 0.87924, saving model to best_model_RDNN.h5
#
# Epoch 00039: val_accuracy improved from 0.87924 to 0.88082, saving model to best_model_RDNN.h5
#
# Epoch 00040: val_accuracy improved from 0.88082 to 0.88141, saving model to best_model_RDNN.h5
#
# Epoch 00041: val_accuracy improved from 0.88141 to 0.88258, saving model to best_model_RDNN.h5
#
# Epoch 00042: val_accuracy did not improve from 0.88258
#
# Epoch 00043: val_accuracy did not improve from 0.88258
#
# Epoch 00044: val_accuracy did not improve from 0.88258
#
# Epoch 00045: val_accuracy did not improve from 0.88258
#
# Epoch 00046: val_accuracy improved from 0.88258 to 0.88358, saving model to best_model_RDNN.h5
# Epoch 00046: early stopping
# Model: "functional_18"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_28 (InputLayer)           [(None, 20, 20)]     0
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 17, 256)      20736       input_28[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_5 (MaxPooling1D)  (None, 7, 256)       0           conv1d_5[0][0]
# __________________________________________________________________________________________________
# lstm_5 (LSTM)                   (None, 20)           22160       max_pooling1d_5[0][0]
# __________________________________________________________________________________________________
# input_29 (InputLayer)           [(None, 7)]          0
# __________________________________________________________________________________________________
# flatten_15 (Flatten)            (None, 20)           0           lstm_5[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 27)           0           input_29[0][0]
#                                                                  flatten_15[0][0]
# __________________________________________________________________________________________________
# dense_43 (Dense)                (None, 90)           2520        concatenate_11[0][0]
# __________________________________________________________________________________________________
# dropout_29 (Dropout)            (None, 90)           0           dense_43[0][0]
# __________________________________________________________________________________________________
# dense_44 (Dense)                (None, 2)            182         dropout_29[0][0]
# ==================================================================================================
# Total params: 45,598
# Trainable params: 45,598
# Non-trainable params: 0
# __________________________________________________________________________________________________
#
# Epoch 00001: val_accuracy improved from -inf to 0.80047, saving model to best_model_RCDNN.h5
#
# Epoch 00002: val_accuracy improved from 0.80047 to 0.83119, saving model to best_model_RCDNN.h5
#
# Epoch 00003: val_accuracy improved from 0.83119 to 0.83573, saving model to best_model_RCDNN.h5
#
# Epoch 00004: val_accuracy improved from 0.83573 to 0.85872, saving model to best_model_RCDNN.h5
#
# Epoch 00005: val_accuracy improved from 0.85872 to 0.87812, saving model to best_model_RCDNN.h5
#
# Epoch 00006: val_accuracy improved from 0.87812 to 0.88243, saving model to best_model_RCDNN.h5
#
# Epoch 00007: val_accuracy improved from 0.88243 to 0.88251, saving model to best_model_RCDNN.h5
#
# Epoch 00008: val_accuracy improved from 0.88251 to 0.89102, saving model to best_model_RCDNN.h5
#
# Epoch 00009: val_accuracy improved from 0.89102 to 0.89844, saving model to best_model_RCDNN.h5
#
# Epoch 00010: val_accuracy did not improve from 0.89844
#
# Epoch 00011: val_accuracy improved from 0.89844 to 0.90479, saving model to best_model_RCDNN.h5
#
# Epoch 00012: val_accuracy improved from 0.90479 to 0.90752, saving model to best_model_RCDNN.h5
#
# Epoch 00013: val_accuracy did not improve from 0.90752
#
# Epoch 00014: val_accuracy did not improve from 0.90752
#
# Epoch 00015: val_accuracy improved from 0.90752 to 0.91667, saving model to best_model_RCDNN.h5
#
# Epoch 00016: val_accuracy did not improve from 0.91667
#
# Epoch 00017: val_accuracy improved from 0.91667 to 0.91812, saving model to best_model_RCDNN.h5
#
# Epoch 00018: val_accuracy improved from 0.91812 to 0.91947, saving model to best_model_RCDNN.h5
#
# Epoch 00019: val_accuracy improved from 0.91947 to 0.92148, saving model to best_model_RCDNN.h5
#
# Epoch 00020: val_accuracy improved from 0.92148 to 0.92327, saving model to best_model_RCDNN.h5
#
# Epoch 00021: val_accuracy improved from 0.92327 to 0.92625, saving model to best_model_RCDNN.h5
#
# Epoch 00022: val_accuracy improved from 0.92625 to 0.92725, saving model to best_model_RCDNN.h5
#
# Epoch 00023: val_accuracy improved from 0.92725 to 0.92990, saving model to best_model_RCDNN.h5
#
# Epoch 00024: val_accuracy did not improve from 0.92990
#
# Epoch 00025: val_accuracy did not improve from 0.92990
#
# Epoch 00026: val_accuracy improved from 0.92990 to 0.93316, saving model to best_model_RCDNN.h5
#
# Epoch 00027: val_accuracy improved from 0.93316 to 0.93831, saving model to best_model_RCDNN.h5
#
# Epoch 00028: val_accuracy did not improve from 0.93831
#
# Epoch 00029: val_accuracy did not improve from 0.93831
#
# Epoch 00030: val_accuracy did not improve from 0.93831
#
# Epoch 00031: val_accuracy did not improve from 0.93831
#
# Epoch 00032: val_accuracy did not improve from 0.93831
#
# Epoch 00033: val_accuracy did not improve from 0.93831
#
# Epoch 00034: val_accuracy improved from 0.93831 to 0.94305, saving model to best_model_RCDNN.h5
#
# Epoch 00035: val_accuracy did not improve from 0.94305
#
# Epoch 00036: val_accuracy did not improve from 0.94305
#
# Epoch 00037: val_accuracy improved from 0.94305 to 0.94364, saving model to best_model_RCDNN.h5
#
# Epoch 00038: val_accuracy did not improve from 0.94364
#
# Epoch 00039: val_accuracy did not improve from 0.94364
# Epoch 00039: early stopping
# convert gdrive/My Drive/data sample/NetMHCpan_processed/test_all.tsv in to sequence and label dataset
# Evaluation for DNN
# 1533/1533 [==============================] - 2s 1ms/step - loss: 0.1261 - accuracy: 0.9527
# Result of model with test set
# loss value: 	0.12608526647090912
# accuracy value: 0.9526858925819397
#
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96     32740
#            1       0.93      0.93      0.93     16294
#
#     accuracy                           0.95     49034
#    macro avg       0.95      0.95      0.95     49034
# weighted avg       0.95      0.95      0.95     49034
#
# ROC-AUC of the DNN model : 0.9465808420697298
# convert gdrive/My Drive/data sample/NetMHCpan_processed/test_all.tsv in to sequence and label dataset
# Evaluation for CDNN
# 1533/1533 [==============================] - 4s 3ms/step - loss: 0.1048 - accuracy: 0.9566
# Result of model with test set
# loss value: 	0.10477691888809204
# accuracy value: 0.9566219449043274
#
#               precision    recall  f1-score   support
#
#            0       0.98      0.95      0.97     32740
#            1       0.91      0.96      0.94     16294
#
#     accuracy                           0.96     49034
#    macro avg       0.95      0.96      0.95     49034
# weighted avg       0.96      0.96      0.96     49034
#
# ROC-AUC of the CDNN model : 0.9587152317761619
# convert gdrive/My Drive/data sample/NetMHCpan_processed/test_all.tsv in to sequence and label dataset
# Evaluation for RDNN
# 1533/1533 [==============================] - 4s 2ms/step - loss: 0.2599 - accuracy: 0.8904
# Result of model with test set
# loss value: 	0.2599295675754547
# accuracy value: 0.8903617858886719
#
#               precision    recall  f1-score   support
#
#            0       0.92      0.92      0.92     32740
#            1       0.83      0.84      0.84     16294
#
#     accuracy                           0.89     49034
#    macro avg       0.88      0.88      0.88     49034
# weighted avg       0.89      0.89      0.89     49034
#
# ROC-AUC of the RDNN model : 0.8772973198119857
# convert gdrive/My Drive/data sample/NetMHCpan_processed/test_all.tsv in to sequence and label dataset
# Evaluation for RCDNN
# 1533/1533 [==============================] - 5s 3ms/step - loss: 0.1155 - accuracy: 0.9551
# Result of model with test set
# loss value: 	0.11550169438123703
# accuracy value: 0.9551127552986145
#
#               precision    recall  f1-score   support
#
#            0       0.98      0.95      0.97     32740
#            1       0.91      0.96      0.93     16294
#
#     accuracy                           0.96     49034
#    macro avg       0.95      0.96      0.95     49034
# weighted avg       0.96      0.96      0.96     49034
#
# ROC-AUC of the RCDNN model : 0.9556274991772665

# %%
allele = "all"
print("Result for %s (data: %d)" %(allele, result["num"]))
print("DNN model")
print("loss %.5f \t accuracy %.5f \t AUC %.5f" 
      %(result["DNN"]["loss"], result["DNN"]["accuracy"], result["DNN"]["auc"]))
print("CDNN model")
print("loss %.5f \t accuracy %.5f \t AUC %.5f" 
      %(result["CDNN"]["loss"], result["CDNN"]["accuracy"], result["CDNN"]["auc"]))
print("RDNN model")
print("loss %.5f \t accuracy %.5f \t AUC %.5f" 
      %(result["RDNN"]["loss"], result["RDNN"]["accuracy"], result["RDNN"]["auc"]))
print("RCDNN model")
print("loss %.5f \t accuracy %.5f \t AUC %.5f" 
      %(result["RCDNN"]["loss"], result["RCDNN"]["accuracy"], result["RCDNN"]["auc"]))
print()
# Out:
# Result for all (data: 196136)
# DNN model
# loss 0.12609 	 accuracy 0.95269 	 AUC 0.94658
# CDNN model
# loss 0.10478 	 accuracy 0.95662 	 AUC 0.95872
# RDNN model
# loss 0.25993 	 accuracy 0.89036 	 AUC 0.87730
# RCDNN model
# loss 0.11550 	 accuracy 0.95511 	 AUC 0.95563
